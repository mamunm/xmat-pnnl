# %%
#Import modules
import numpy as np
import pandas as pd
import xmat_pnnl_code as xcode

# %%
#Load the data
data_df, fetures_description, alloy_metadata = xcode.load_data('Aus_Steel_Data')

# %%
data_df
# Out:
#           ID      Fe     C    Cr    Mn    Si       Ni   Co   Mo    W  ...  \
# 13   AUS_001  67.513  0.09  18.2  1.57   0.4    11.32  NaN  NaN  NaN  ...
# 14   AUS_001  67.513  0.09  18.2  1.57   0.4    11.32  NaN  NaN  NaN  ...
# 15   AUS_001  67.513  0.09  18.2  1.57   0.4    11.32  NaN  NaN  NaN  ...
# 16   AUS_001  67.513  0.09  18.2  1.57   0.4    11.32  NaN  NaN  NaN  ...
# 17   AUS_001  67.513  0.09  18.2  1.57   0.4    11.32  NaN  NaN  NaN  ...
# ..       ...     ...   ...   ...   ...   ...      ...  ...  ...  ...  ...
# 725  AUS_018    18.7  0.06  21.1  0.48  0.35  48.0392  1.4  8.8  0.6  ...
# 728  AUS_018    18.7  0.06  21.1  0.48  0.35  48.0392  1.4  8.8  0.6  ...
# 729  AUS_018    18.7  0.06  21.1  0.48  0.35  48.0392  1.4  8.8  0.6  ...
# 730  AUS_018    18.7  0.06  21.1  0.48  0.35  48.0392  1.4  8.8  0.6  ...
# 731  AUS_018    18.7  0.06  21.1  0.48  0.35  48.0392  1.4  8.8  0.6  ...
#
#     CT_CS    CT_RT CT_EL CT_RA   CT_MCR CT_0.5% CS CT_1.0% CS CT_2.0% CS  \
# ...
